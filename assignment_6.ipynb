# %% [markdown]
# <a href="https://colab.research.google.com/github/jd-mnn/big-data/blob/master/assignment_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
system("ls",TRUE)
library(readr)
dataset<-read.csv("ah.csv")
dataset
# Out:
# [1] "ah.csv"                 "averageheightof15y.csv" "sample_data"
#     學年度 年齡 總計  男    女
# 1   96      6   117.1 117.6 116.6
# 2   96      7   121.4 121.9 120.9
# 3   96      8   127.1 127.5 126.7
# 4   96      9   132.8 132.9 132.6
# 5   96     10   138.8 138.5 139.3
# 6   96     11   145.0 144.2 145.9
# 7   96     12   151.4 151.2 151.6
# 8   96     13   157.1 158.9 155.3
# 9   96     14   161.1 164.7 157.3
# 10  96     15   163.2 167.8 158.1
# 11  97      6   117.2 117.6 116.7
# 12  97      7   121.5 121.9 120.9
# 13  97      8   127.3 127.7 126.8
# 14  97      9   132.9 133.1 132.7
# 15  97     10   138.8 138.4 139.1
# 16  97     11   145.3 144.5 146.1
# 17  97     12   151.4 151.3 151.6
# 18  97     13   157.2 158.9 155.4
# 19  97     14   161.3 165.0 157.3
# 20  97     15   163.3 168.0 158.2
# 21  98      6   117.3 117.8 116.8
# 22  98      7   121.6 122.0 121.1
# 23  98      8   127.3 127.7 126.8
# 24  98      9   133.0 133.2 132.8
# 25  98     10   138.8 138.4 139.1
# ...

# %%
install.packages("ggplot2")
library(ggplot2)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
ggplot(data=dataset,aes(x=男,y=總計))+geom_point()
# Out:
# plot without title

# %%
ggplot(data=dataset,aes(x=女,y=總計))+geom_point()
# Out:
# plot without title

# %%
ggplot(data=dataset,aes(y=男,x=年齡))+geom_violin()
# Out:
# plot without title

# %%
ggplot(data=dataset,aes(y=總計,x=年齡))+geom_violin()
# Out:
# plot without title

# %%
qplot(男,年齡,data=dataset,geom=c("point","smooth"))
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
qplot(女,年齡,data=dataset,geom=c("point","smooth"))
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
qplot(總計,data=dataset,fill=學年度)
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
qplot(男,data=dataset,fill=年齡)
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
boxplot(dataset$女)
# Out:
# plot without title

# %%
boxplot(dataset$男)
# Out:
# plot without title
