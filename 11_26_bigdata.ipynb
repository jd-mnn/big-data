# %% [markdown]
# <a href="https://colab.research.google.com/github/jd-mnn/big-data/blob/master/11_26_bigdata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
system("ls",TRUE)
# Out:
# [1] "sample_data"      "臺中市人口數.csv"

# %%
pkgs<-c("tidyverse","lubridate")
install.packages(pkgs)
# Out:
# Installing packages into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(tidyverse)
library(lubridate)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.3.2     ✔ purrr   0.3.4
# ✔ tibble  3.0.4     ✔ dplyr   1.0.2
# ✔ tidyr   1.1.2     ✔ stringr 1.4.0
# ✔ readr   1.4.0     ✔ forcats 0.5.0
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
#
# Attaching package: ‘lubridate’
#
#
# The following objects are masked from ‘package:base’:
#
#     date, intersect, setdiff, union

# %%
population<-read.csv("臺中市人口數.csv")

# %%
population
# Out:
#    區域別 區數 里數 鄰數 戶數   總人口數 男人口數 女人口數 原住民人口數
# 1  中區   1     8    195   7961  18173     8994     9179    133
# 2  東區   1    17    404  28767  75769    37529    38240    707
# 3  南區   1    22    608  50140 126585    60523    66062   1032
# 4  西區   1    25    608  46296 114618    54255    60363    574
# 5  北區   1    36    842  60561 146676    69912    76764   1336
# 6  西屯區 1    39   1006  89639 230978   110607   120371   1924
# 7  南屯區 1    25    597  66421 175439    83806    91633   1368
# 8  北屯區 1    42    934 106863 286208   136621   149587   2992
# 9  豐原區 1    36    737  55108 166199    81915    84284   1602
# 10 東勢區 1    25    343  17501  49250    25254    23996    750
# 11 大甲區 1    29    376  23761  76116    38198    37918    311
# 12 清水區 1    32    496  29148  87863    44878    42985    638
# 13 沙鹿區 1    21    412  31236  95135    47849    47286   1021
# 14 梧棲區 1    14    342  18974  59199    29639    29560    967
# 15 后里區 1    18    263  16771  54374    27556    26818    647
# ...

# %%
install.packages("ggplot2")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(ggplot2)

# %%
install.packages("devtools")
devtools::install_github('cttobin/ggthemr')

library(ggthemr)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# ...
# rlang      (0.4.8 -> 0.4.9) [CRAN]
# vctrs      (0.3.4 -> 0.3.5) [CRAN]
# pillar     (1.4.6 -> 1.4.7) [CRAN]
# magrittr   (1.5   -> 2.0.1) [CRAN]
# cli        (2.1.0 -> 2.2.0) [CRAN]
# rstudioapi (0.12  -> 0.13 ) [CRAN]
# rprojroot  (1.3-2 -> 2.0.2) [CRAN]
# processx   (3.4.4 -> 3.4.5) [CRAN]
# isoband    (0.2.2 -> 0.2.3) [CRAN]
# Installing 9 packages: rlang, vctrs, pillar, magrittr, cli, rstudioapi, rprojroot, processx, isoband
#
# Installing packages into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
# ✔  checking for file ‘/tmp/Rtmpr1Gj0N/remotes38643eaa7f/Mikata-Project-ggthemr-3a86e28/DESCRIPTION’
# ─  preparing ‘ggthemr’:
# ✔  checking DESCRIPTION meta-information
# ─  checking for LF line-endings in source and make files and shell scripts
# ─  checking for empty or unneeded directories
#    Removed empty directory ‘ggthemr/README_files’
# ─  building ‘ggthemr_1.1.0.tar.gz’
# ...

# %%
ggthemr("dust")

# %%
#各區域的里數比較

# %%
ggplot()+geom_bar(data=population,aes(x=區域別,y=里數),stat="identity")
# Out:
# plot without title

# %%
#各區間男人口數比較

# %%
ggplot()+geom_bar(data=population,aes(x=區域別,y=男人口數),stat="identity")
# Out:
# plot without title

# %%
#各區間原住民人口數比較

# %%
ggplot()+geom_bar(data=population,aes(x=區域別,y=原住民人口數),stat="identity")
# Out:
# plot without title

# %%
#各區間人口增加數比較

# %%
ggplot()+geom_bar(data=population,aes(x=區域別,y=人口增加數),stat="identity")
# Out:
# plot without title
